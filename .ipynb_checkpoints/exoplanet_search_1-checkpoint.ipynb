# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

# %%
exoplanets = pd.read_csv(os.path.join('Resources', 'cumulative.csv'))
pd.set_option('display.max_columns', None)
exoplanets
# Out:
#       rowid     kepid kepoi_name   kepler_name koi_disposition  \
# 0         1  10797460  K00752.01  Kepler-227 b       CONFIRMED
# 1         2  10797460  K00752.02  Kepler-227 c       CONFIRMED
# 2         3  10811496  K00753.01           NaN  FALSE POSITIVE
# 3         4  10848459  K00754.01           NaN  FALSE POSITIVE
# 4         5  10854555  K00755.01  Kepler-664 b       CONFIRMED
# ...     ...       ...        ...           ...             ...
# 9559   9560  10031643  K07984.01           NaN  FALSE POSITIVE
# 9560   9561  10090151  K07985.01           NaN  FALSE POSITIVE
# 9561   9562  10128825  K07986.01           NaN       CANDIDATE
# 9562   9563  10147276  K07987.01           NaN  FALSE POSITIVE
# 9563   9564  10156110  K07989.01           NaN  FALSE POSITIVE
#
#      koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0           CANDIDATE      1.000              0              0              0
# 1           CANDIDATE      0.969              0              0              0
# 2      FALSE POSITIVE      0.000              0              1              0
# 3      FALSE POSITIVE      0.000              0              1              0
# 4           CANDIDATE      1.000              0              0              0
# ...               ...        ...            ...            ...            ...
# 9559   FALSE POSITIVE      0.000              0              0              0
# 9560   FALSE POSITIVE      0.000              0              1              1
# 9561        CANDIDATE      0.497              0              0              0
# 9562   FALSE POSITIVE      0.021              0              0              1
# 9563   FALSE POSITIVE      0.000              0              0              1
#
#       koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  \
# 0                 0    9.488036     2.775000e-05    -2.775000e-05
# 1                 0   54.418383     2.479000e-04    -2.479000e-04
# 2                 0   19.899140     1.494000e-05    -1.494000e-05
# 3                 0    1.736952     2.630000e-07    -2.630000e-07
# 4                 0    2.525592     3.761000e-06    -3.761000e-06
# ...             ...         ...              ...              ...
# 9559              1    8.589871     1.846000e-04    -1.846000e-04
# 9560              0    0.527699     1.160000e-07    -1.160000e-07
# 9561              0    1.739849     1.780000e-05    -1.780000e-05
# 9562              0    0.681402     2.434000e-06    -2.434000e-06
# 9563              1    4.856035     6.356000e-05    -6.356000e-05
#
#       koi_time0bk  koi_time0bk_err1  koi_time0bk_err2  koi_impact  \
# 0      170.538750          0.002160         -0.002160       0.146
# 1      162.513840          0.003520         -0.003520       0.586
# 2      175.850252          0.000581         -0.000581       0.969
# 3      170.307565          0.000115         -0.000115       1.276
# 4      171.595550          0.001130         -0.001130       0.701
# ...           ...               ...               ...         ...
# 9559   132.016100          0.015700         -0.015700       0.765
# 9560   131.705093          0.000170         -0.000170       1.252
# 9561   133.001270          0.007690         -0.007690       0.043
# 9562   132.181750          0.002850         -0.002850       0.147
# 9563   135.993300          0.010800         -0.010800       0.134
#
#       koi_impact_err1  koi_impact_err2  koi_duration  koi_duration_err1  \
# 0               0.318           -0.146       2.95750            0.08190
# 1               0.059           -0.443       4.50700            0.11600
# 2               5.126           -0.077       1.78220            0.03410
# 3               0.115           -0.092       2.40641            0.00537
# 4               0.235           -0.478       1.65450            0.04200
# ...               ...              ...           ...                ...
# 9559            0.023           -0.541       4.80600            0.63400
# 9560            0.051           -0.049       3.22210            0.01740
# 9561            0.423           -0.043       3.11400            0.22900
# 9562            0.309           -0.147       0.86500            0.16200
# 9563            0.323           -0.134       3.07800            0.28300
#
#       koi_duration_err2  koi_depth  koi_depth_err1  koi_depth_err2  koi_prad  \
# 0              -0.08190      615.8            19.5           -19.5      2.26
# 1              -0.11600      874.8            35.5           -35.5      2.83
# 2              -0.03410    10829.0           171.0          -171.0     14.60
# 3              -0.00537     8079.2            12.8           -12.8     33.46
# 4              -0.04200      603.3            16.9           -16.9      2.75
# ...                 ...        ...             ...             ...       ...
# 9559           -0.63400       87.7            13.0           -13.0      1.11
# 9560           -0.01740     1579.2             4.6            -4.6     29.35
# 9561           -0.22900       48.5             5.4            -5.4      0.72
# 9562           -0.16200      103.6            14.7           -14.7      1.07
# 9563           -0.28300       76.7            10.8           -10.8      1.05
#
#       koi_prad_err1  koi_prad_err2  koi_teq  koi_teq_err1  koi_teq_err2  \
# 0              0.26          -0.15    793.0           NaN           NaN
# 1              0.32          -0.19    443.0           NaN           NaN
# 2              3.92          -1.31    638.0           NaN           NaN
# 3              8.50          -2.83   1395.0           NaN           NaN
# 4              0.88          -0.35   1406.0           NaN           NaN
# ...             ...            ...      ...           ...           ...
# 9559           0.32          -0.23    929.0           NaN           NaN
# 9560           7.70          -2.57   2088.0           NaN           NaN
# 9561           0.24          -0.08   1608.0           NaN           NaN
# 9562           0.36          -0.11   2218.0           NaN           NaN
# 9563           0.36          -0.12   1266.0           NaN           NaN
#
#       koi_insol  koi_insol_err1  koi_insol_err2  koi_model_snr  \
# 0         93.59           29.45          -16.65           35.8
# 1          9.11            2.87           -1.62           25.8
# 2         39.30           31.04          -10.49           76.3
# 3        891.96          668.95         -230.35          505.6
# 4        926.16          874.33         -314.24           40.9
# ...         ...             ...             ...            ...
# 9559     176.40          152.77          -77.60            8.4
# 9560    4500.53         3406.38        -1175.26          453.3
# 9561    1585.81         1537.86         -502.22           10.6
# 9562    5713.41         5675.74        -1836.94           12.3
# 9563     607.42          600.39         -194.33            8.2
#
#       koi_tce_plnt_num koi_tce_delivname  koi_steff  koi_steff_err1  \
# 0                  1.0   q1_q17_dr25_tce     5455.0            81.0
# 1                  2.0   q1_q17_dr25_tce     5455.0            81.0
# 2                  1.0   q1_q17_dr25_tce     5853.0           158.0
# 3                  1.0   q1_q17_dr25_tce     5805.0           157.0
# 4                  1.0   q1_q17_dr25_tce     6031.0           169.0
# ...                ...               ...        ...             ...
# 9559               1.0   q1_q17_dr25_tce     5638.0           169.0
# 9560               1.0   q1_q17_dr25_tce     5638.0           139.0
# 9561               1.0   q1_q17_dr25_tce     6119.0           165.0
# 9562               1.0   q1_q17_dr25_tce     6173.0           193.0
# 9563               1.0   q1_q17_dr25_tce     6469.0           158.0
#
#       koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# 0              -81.0      4.467           0.064          -0.096     0.927
# 1              -81.0      4.467           0.064          -0.096     0.927
# 2             -176.0      4.544           0.044          -0.176     0.868
# 3             -174.0      4.564           0.053          -0.168     0.791
# 4             -211.0      4.438           0.070          -0.210     1.046
# ...              ...        ...             ...             ...       ...
# 9559          -152.0      4.296           0.231          -0.189     1.088
# 9560          -166.0      4.529           0.035          -0.196     0.903
# 9561          -220.0      4.444           0.056          -0.224     1.031
# 9562          -236.0      4.447           0.056          -0.224     1.041
# 9563          -225.0      4.385           0.054          -0.216     1.193
#
#       koi_srad_err1  koi_srad_err2         ra        dec  koi_kepmag
# 0             0.105         -0.061  291.93423  48.141651      15.347
# 1             0.105         -0.061  291.93423  48.141651      15.347
# 2             0.233         -0.078  297.00482  48.134129      15.436
# 3             0.201         -0.067  285.53461  48.285210      15.597
# 4             0.334         -0.133  288.75488  48.226200      15.509
# ...             ...            ...        ...        ...         ...
# 9559          0.313         -0.228  298.74921  46.973351      14.478
# 9560          0.237         -0.079  297.18875  47.093819      14.082
# 9561          0.341         -0.114  286.50937  47.163219      14.757
# 9562          0.341         -0.114  294.16489  47.176281      15.385
# 9563          0.410         -0.137  297.00977  47.121021      14.826
#
# [9564 rows x 50 columns]

# %% [markdown]
# At least for now: keeping all columns in case of later interest, but removing derived columns from predictions
#
# Evaluations for comparison: koi_pdisposition (use only rows where value is FALSE POSITIVE or CANDIDATE, since others (mostly?) have incomplete data); koi_score
#
# ID to use: kepoi_name
# ID columns to ignore: kepid, kepler_name, rowid
# Evaluations to ignore (for now): koi_disposition, koi_vet_stat, koi_vet_date, koi_disp_prov, koi_comment, koi_fittype, k_limbdark_mod, koi_parm_prov, koi_time0 (same info as koi_time0bk), koi_fittype (describes analytical methods - might be related to other variablesbut secondary), koi_limbdark_mod	(describes analytical method)
# koi_ldm_coeff1, koi_ldm_coeff2, koi_ldm_coeff3, koi_ldm_coeff4 (fitted parameters...)
# koi_tce_plnt_num, koi_tce_delivname, koi_quarters
# koi_trans_mod, koi_model_dof
# koi_datalink_dvr, koi_datalink_dvs
# koi_ror, koi_prad ... are calculated, but kept it in for now

# %%
#Remove rows (if any) where koi_pdisposition is not FALSE POSITIVE or CANDIDATE; koi_disposition has additional categories
exoplanets.koi_pdisposition.unique()
#None found in current file
# Out:
# array(['CANDIDATE', 'FALSE POSITIVE'], dtype=object)

# %%
#Make koi_pdisposition and koi_disposition numerical variables, see if they are the same (no, )
exoplanets_pdisp_cat = pd.get_dummies(exoplanets, prefix=['koi_pdisposition'], columns=['koi_pdisposition'])
#
exoplanets_pdisp_cat
# Out:
#       rowid     kepid kepoi_name   kepler_name koi_disposition  koi_score  \
# 0         1  10797460  K00752.01  Kepler-227 b       CONFIRMED      1.000
# 1         2  10797460  K00752.02  Kepler-227 c       CONFIRMED      0.969
# 2         3  10811496  K00753.01           NaN  FALSE POSITIVE      0.000
# 3         4  10848459  K00754.01           NaN  FALSE POSITIVE      0.000
# 4         5  10854555  K00755.01  Kepler-664 b       CONFIRMED      1.000
# ...     ...       ...        ...           ...             ...        ...
# 9559   9560  10031643  K07984.01           NaN  FALSE POSITIVE      0.000
# 9560   9561  10090151  K07985.01           NaN  FALSE POSITIVE      0.000
# 9561   9562  10128825  K07986.01           NaN       CANDIDATE      0.497
# 9562   9563  10147276  K07987.01           NaN  FALSE POSITIVE      0.021
# 9563   9564  10156110  K07989.01           NaN  FALSE POSITIVE      0.000
#
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0                 0              0              0              0    9.488036
# 1                 0              0              0              0   54.418383
# 2                 0              1              0              0   19.899140
# 3                 0              1              0              0    1.736952
# 4                 0              0              0              0    2.525592
# ...             ...            ...            ...            ...         ...
# 9559              0              0              0              1    8.589871
# 9560              0              1              1              0    0.527699
# 9561              0              0              0              0    1.739849
# 9562              0              0              1              0    0.681402
# 9563              0              0              1              1    4.856035
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0        2.775000e-05    -2.775000e-05   170.538750          0.002160
# 1        2.479000e-04    -2.479000e-04   162.513840          0.003520
# 2        1.494000e-05    -1.494000e-05   175.850252          0.000581
# 3        2.630000e-07    -2.630000e-07   170.307565          0.000115
# 4        3.761000e-06    -3.761000e-06   171.595550          0.001130
# ...               ...              ...          ...               ...
# 9559     1.846000e-04    -1.846000e-04   132.016100          0.015700
# 9560     1.160000e-07    -1.160000e-07   131.705093          0.000170
# 9561     1.780000e-05    -1.780000e-05   133.001270          0.007690
# 9562     2.434000e-06    -2.434000e-06   132.181750          0.002850
# 9563     6.356000e-05    -6.356000e-05   135.993300          0.010800
#
#       koi_time0bk_err2  koi_impact  koi_impact_err1  koi_impact_err2  \
# 0            -0.002160       0.146            0.318           -0.146
# 1            -0.003520       0.586            0.059           -0.443
# 2            -0.000581       0.969            5.126           -0.077
# 3            -0.000115       1.276            0.115           -0.092
# 4            -0.001130       0.701            0.235           -0.478
# ...                ...         ...              ...              ...
# 9559         -0.015700       0.765            0.023           -0.541
# 9560         -0.000170       1.252            0.051           -0.049
# 9561         -0.007690       0.043            0.423           -0.043
# 9562         -0.002850       0.147            0.309           -0.147
# 9563         -0.010800       0.134            0.323           -0.134
#
#       koi_duration  koi_duration_err1  koi_duration_err2  koi_depth  \
# 0          2.95750            0.08190           -0.08190      615.8
# 1          4.50700            0.11600           -0.11600      874.8
# 2          1.78220            0.03410           -0.03410    10829.0
# 3          2.40641            0.00537           -0.00537     8079.2
# 4          1.65450            0.04200           -0.04200      603.3
# ...            ...                ...                ...        ...
# 9559       4.80600            0.63400           -0.63400       87.7
# 9560       3.22210            0.01740           -0.01740     1579.2
# 9561       3.11400            0.22900           -0.22900       48.5
# 9562       0.86500            0.16200           -0.16200      103.6
# 9563       3.07800            0.28300           -0.28300       76.7
#
#       koi_depth_err1  koi_depth_err2  koi_prad  koi_prad_err1  koi_prad_err2  \
# 0               19.5           -19.5      2.26           0.26          -0.15
# 1               35.5           -35.5      2.83           0.32          -0.19
# 2              171.0          -171.0     14.60           3.92          -1.31
# 3               12.8           -12.8     33.46           8.50          -2.83
# 4               16.9           -16.9      2.75           0.88          -0.35
# ...              ...             ...       ...            ...            ...
# 9559            13.0           -13.0      1.11           0.32          -0.23
# 9560             4.6            -4.6     29.35           7.70          -2.57
# 9561             5.4            -5.4      0.72           0.24          -0.08
# 9562            14.7           -14.7      1.07           0.36          -0.11
# 9563            10.8           -10.8      1.05           0.36          -0.12
#
#       koi_teq  koi_teq_err1  koi_teq_err2  koi_insol  koi_insol_err1  \
# 0       793.0           NaN           NaN      93.59           29.45
# 1       443.0           NaN           NaN       9.11            2.87
# 2       638.0           NaN           NaN      39.30           31.04
# 3      1395.0           NaN           NaN     891.96          668.95
# 4      1406.0           NaN           NaN     926.16          874.33
# ...       ...           ...           ...        ...             ...
# 9559    929.0           NaN           NaN     176.40          152.77
# 9560   2088.0           NaN           NaN    4500.53         3406.38
# 9561   1608.0           NaN           NaN    1585.81         1537.86
# 9562   2218.0           NaN           NaN    5713.41         5675.74
# 9563   1266.0           NaN           NaN     607.42          600.39
#
#       koi_insol_err2  koi_model_snr  koi_tce_plnt_num koi_tce_delivname  \
# 0             -16.65           35.8               1.0   q1_q17_dr25_tce
# 1              -1.62           25.8               2.0   q1_q17_dr25_tce
# 2             -10.49           76.3               1.0   q1_q17_dr25_tce
# 3            -230.35          505.6               1.0   q1_q17_dr25_tce
# 4            -314.24           40.9               1.0   q1_q17_dr25_tce
# ...              ...            ...               ...               ...
# 9559          -77.60            8.4               1.0   q1_q17_dr25_tce
# 9560        -1175.26          453.3               1.0   q1_q17_dr25_tce
# 9561         -502.22           10.6               1.0   q1_q17_dr25_tce
# 9562        -1836.94           12.3               1.0   q1_q17_dr25_tce
# 9563         -194.33            8.2               1.0   q1_q17_dr25_tce
#
#       koi_steff  koi_steff_err1  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0        5455.0            81.0           -81.0      4.467           0.064
# 1        5455.0            81.0           -81.0      4.467           0.064
# 2        5853.0           158.0          -176.0      4.544           0.044
# 3        5805.0           157.0          -174.0      4.564           0.053
# 4        6031.0           169.0          -211.0      4.438           0.070
# ...         ...             ...             ...        ...             ...
# 9559     5638.0           169.0          -152.0      4.296           0.231
# 9560     5638.0           139.0          -166.0      4.529           0.035
# 9561     6119.0           165.0          -220.0      4.444           0.056
# 9562     6173.0           193.0          -236.0      4.447           0.056
# 9563     6469.0           158.0          -225.0      4.385           0.054
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0             -0.096     0.927          0.105         -0.061  291.93423
# 1             -0.096     0.927          0.105         -0.061  291.93423
# 2             -0.176     0.868          0.233         -0.078  297.00482
# 3             -0.168     0.791          0.201         -0.067  285.53461
# 4             -0.210     1.046          0.334         -0.133  288.75488
# ...              ...       ...            ...            ...        ...
# 9559          -0.189     1.088          0.313         -0.228  298.74921
# 9560          -0.196     0.903          0.237         -0.079  297.18875
# 9561          -0.224     1.031          0.341         -0.114  286.50937
# 9562          -0.224     1.041          0.341         -0.114  294.16489
# 9563          -0.216     1.193          0.410         -0.137  297.00977
#
#             dec  koi_kepmag  koi_pdisposition_CANDIDATE  \
# 0     48.141651      15.347                           1
# 1     48.141651      15.347                           1
# 2     48.134129      15.436                           0
# 3     48.285210      15.597                           0
# 4     48.226200      15.509                           1
# ...         ...         ...                         ...
# 9559  46.973351      14.478                           0
# 9560  47.093819      14.082                           0
# 9561  47.163219      14.757                           1
# 9562  47.176281      15.385                           0
# 9563  47.121021      14.826                           0
#
#       koi_pdisposition_FALSE POSITIVE
# 0                                   0
# 1                                   0
# 2                                   1
# 3                                   1
# 4                                   0
# ...                               ...
# 9559                                1
# 9560                                1
# 9561                                0
# 9562                                1
# 9563                                1
#
# [9564 rows x 51 columns]

# %%
exoplanets_disp_cat = pd.get_dummies(exoplanets_pdisp_cat, prefix=['koi_disposition'], columns=['koi_disposition'])
exoplanets_disp_cat.drop('koi_pdisposition_FALSE POSITIVE', axis=1, inplace=True)

exoplanets_disp_cat
# Out:
#       rowid     kepid kepoi_name   kepler_name  koi_score  koi_fpflag_nt  \
# 0         1  10797460  K00752.01  Kepler-227 b      1.000              0
# 1         2  10797460  K00752.02  Kepler-227 c      0.969              0
# 2         3  10811496  K00753.01           NaN      0.000              0
# 3         4  10848459  K00754.01           NaN      0.000              0
# 4         5  10854555  K00755.01  Kepler-664 b      1.000              0
# ...     ...       ...        ...           ...        ...            ...
# 9559   9560  10031643  K07984.01           NaN      0.000              0
# 9560   9561  10090151  K07985.01           NaN      0.000              0
# 9561   9562  10128825  K07986.01           NaN      0.497              0
# 9562   9563  10147276  K07987.01           NaN      0.021              0
# 9563   9564  10156110  K07989.01           NaN      0.000              0
#
#       koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0                 0              0              0    9.488036
# 1                 0              0              0   54.418383
# 2                 1              0              0   19.899140
# 3                 1              0              0    1.736952
# 4                 0              0              0    2.525592
# ...             ...            ...            ...         ...
# 9559              0              0              1    8.589871
# 9560              1              1              0    0.527699
# 9561              0              0              0    1.739849
# 9562              0              1              0    0.681402
# 9563              0              1              1    4.856035
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0        2.775000e-05    -2.775000e-05   170.538750          0.002160
# 1        2.479000e-04    -2.479000e-04   162.513840          0.003520
# 2        1.494000e-05    -1.494000e-05   175.850252          0.000581
# 3        2.630000e-07    -2.630000e-07   170.307565          0.000115
# 4        3.761000e-06    -3.761000e-06   171.595550          0.001130
# ...               ...              ...          ...               ...
# 9559     1.846000e-04    -1.846000e-04   132.016100          0.015700
# 9560     1.160000e-07    -1.160000e-07   131.705093          0.000170
# 9561     1.780000e-05    -1.780000e-05   133.001270          0.007690
# 9562     2.434000e-06    -2.434000e-06   132.181750          0.002850
# 9563     6.356000e-05    -6.356000e-05   135.993300          0.010800
#
#       koi_time0bk_err2  koi_impact  koi_impact_err1  koi_impact_err2  \
# 0            -0.002160       0.146            0.318           -0.146
# 1            -0.003520       0.586            0.059           -0.443
# 2            -0.000581       0.969            5.126           -0.077
# 3            -0.000115       1.276            0.115           -0.092
# 4            -0.001130       0.701            0.235           -0.478
# ...                ...         ...              ...              ...
# 9559         -0.015700       0.765            0.023           -0.541
# 9560         -0.000170       1.252            0.051           -0.049
# 9561         -0.007690       0.043            0.423           -0.043
# 9562         -0.002850       0.147            0.309           -0.147
# 9563         -0.010800       0.134            0.323           -0.134
#
#       koi_duration  koi_duration_err1  koi_duration_err2  koi_depth  \
# 0          2.95750            0.08190           -0.08190      615.8
# 1          4.50700            0.11600           -0.11600      874.8
# 2          1.78220            0.03410           -0.03410    10829.0
# 3          2.40641            0.00537           -0.00537     8079.2
# 4          1.65450            0.04200           -0.04200      603.3
# ...            ...                ...                ...        ...
# 9559       4.80600            0.63400           -0.63400       87.7
# 9560       3.22210            0.01740           -0.01740     1579.2
# 9561       3.11400            0.22900           -0.22900       48.5
# 9562       0.86500            0.16200           -0.16200      103.6
# 9563       3.07800            0.28300           -0.28300       76.7
#
#       koi_depth_err1  koi_depth_err2  koi_prad  koi_prad_err1  koi_prad_err2  \
# 0               19.5           -19.5      2.26           0.26          -0.15
# 1               35.5           -35.5      2.83           0.32          -0.19
# 2              171.0          -171.0     14.60           3.92          -1.31
# 3               12.8           -12.8     33.46           8.50          -2.83
# 4               16.9           -16.9      2.75           0.88          -0.35
# ...              ...             ...       ...            ...            ...
# 9559            13.0           -13.0      1.11           0.32          -0.23
# 9560             4.6            -4.6     29.35           7.70          -2.57
# 9561             5.4            -5.4      0.72           0.24          -0.08
# 9562            14.7           -14.7      1.07           0.36          -0.11
# 9563            10.8           -10.8      1.05           0.36          -0.12
#
#       koi_teq  koi_teq_err1  koi_teq_err2  koi_insol  koi_insol_err1  \
# 0       793.0           NaN           NaN      93.59           29.45
# 1       443.0           NaN           NaN       9.11            2.87
# 2       638.0           NaN           NaN      39.30           31.04
# 3      1395.0           NaN           NaN     891.96          668.95
# 4      1406.0           NaN           NaN     926.16          874.33
# ...       ...           ...           ...        ...             ...
# 9559    929.0           NaN           NaN     176.40          152.77
# 9560   2088.0           NaN           NaN    4500.53         3406.38
# 9561   1608.0           NaN           NaN    1585.81         1537.86
# 9562   2218.0           NaN           NaN    5713.41         5675.74
# 9563   1266.0           NaN           NaN     607.42          600.39
#
#       koi_insol_err2  koi_model_snr  koi_tce_plnt_num koi_tce_delivname  \
# 0             -16.65           35.8               1.0   q1_q17_dr25_tce
# 1              -1.62           25.8               2.0   q1_q17_dr25_tce
# 2             -10.49           76.3               1.0   q1_q17_dr25_tce
# 3            -230.35          505.6               1.0   q1_q17_dr25_tce
# 4            -314.24           40.9               1.0   q1_q17_dr25_tce
# ...              ...            ...               ...               ...
# 9559          -77.60            8.4               1.0   q1_q17_dr25_tce
# 9560        -1175.26          453.3               1.0   q1_q17_dr25_tce
# 9561         -502.22           10.6               1.0   q1_q17_dr25_tce
# 9562        -1836.94           12.3               1.0   q1_q17_dr25_tce
# 9563         -194.33            8.2               1.0   q1_q17_dr25_tce
#
#       koi_steff  koi_steff_err1  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0        5455.0            81.0           -81.0      4.467           0.064
# 1        5455.0            81.0           -81.0      4.467           0.064
# 2        5853.0           158.0          -176.0      4.544           0.044
# 3        5805.0           157.0          -174.0      4.564           0.053
# 4        6031.0           169.0          -211.0      4.438           0.070
# ...         ...             ...             ...        ...             ...
# 9559     5638.0           169.0          -152.0      4.296           0.231
# 9560     5638.0           139.0          -166.0      4.529           0.035
# 9561     6119.0           165.0          -220.0      4.444           0.056
# 9562     6173.0           193.0          -236.0      4.447           0.056
# 9563     6469.0           158.0          -225.0      4.385           0.054
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0             -0.096     0.927          0.105         -0.061  291.93423
# 1             -0.096     0.927          0.105         -0.061  291.93423
# 2             -0.176     0.868          0.233         -0.078  297.00482
# 3             -0.168     0.791          0.201         -0.067  285.53461
# 4             -0.210     1.046          0.334         -0.133  288.75488
# ...              ...       ...            ...            ...        ...
# 9559          -0.189     1.088          0.313         -0.228  298.74921
# 9560          -0.196     0.903          0.237         -0.079  297.18875
# 9561          -0.224     1.031          0.341         -0.114  286.50937
# 9562          -0.224     1.041          0.341         -0.114  294.16489
# 9563          -0.216     1.193          0.410         -0.137  297.00977
#
#             dec  koi_kepmag  koi_pdisposition_CANDIDATE  \
# 0     48.141651      15.347                           1
# 1     48.141651      15.347                           1
# 2     48.134129      15.436                           0
# 3     48.285210      15.597                           0
# 4     48.226200      15.509                           1
# ...         ...         ...                         ...
# 9559  46.973351      14.478                           0
# 9560  47.093819      14.082                           0
# 9561  47.163219      14.757                           1
# 9562  47.176281      15.385                           0
# 9563  47.121021      14.826                           0
#
#       koi_disposition_CANDIDATE  koi_disposition_CONFIRMED  \
# 0                             0                          1
# 1                             0                          1
# 2                             0                          0
# 3                             0                          0
# 4                             0                          1
# ...                         ...                        ...
# 9559                          0                          0
# 9560                          0                          0
# 9561                          1                          0
# 9562                          0                          0
# 9563                          0                          0
#
#       koi_disposition_FALSE POSITIVE
# 0                                  0
# 1                                  0
# 2                                  1
# 3                                  1
# 4                                  0
# ...                              ...
# 9559                               1
# 9560                               1
# 9561                               0
# 9562                               1
# 9563                               1
#
# [9564 rows x 52 columns]

# %% [markdown]
# **Remember to drop koi_pdisposition_CANDIDATE
# For a basic set: X = exoplanets_disp_cat[["koi_fpflag_nt", "koi_fpflag_ss", "koi_fpflag_co", "koi_fpflag_ec", "koi_period", "koi_time0bk", "koi_impact","koi_duration", "koi_depth", "koi_prad", "koi_teq", "koi_insol", "koi_model_snr", "koi_steff", "koi_slogg", "koi_srad", "ra", "dec", "koi_kepmag"]]
#
# For basic set, drop ("rowid", "kepid", "kepoi_name", "kepler_name", "koi_score", "koi_period_err1", "koi_period_err2", "koi_time0bk_err1", "koi_time0bk_err2", "koi_impact_err1", "koi_impact_err2", "koi_duration_err1", "koi_duration_err2", "koi_depth_err1", "koi_depth_err2", "koi_prad_err1", "koi_prad_err2", "koi_teq_err1", "koi_teq_err2", "koi_insol_err1", "koi_insol_err2", "koi_tce_plnt_num", "koi_tce_delivname","koi_steff_err1", "koi_steff_err2", "koi_slogg_err1", "koi_slogg_err2", "koi_srad_err1", "koi_srad_err2", "koi_disposition_CANDIDATE", "koi_disposition_CONFIRMED", "koi_disposition_FALSE POSITIVE")
#
# y = exoplanets_disp_cat[[koi_pdisposition_CANDIDATE]]

# %%
exoplanets_basic = exoplanets_disp_cat.drop(["rowid", "kepid", "kepler_name", "koi_score", "koi_period_err1", "koi_period_err2", "koi_time0bk_err1", "koi_time0bk_err2", "koi_impact_err1", "koi_impact_err2", "koi_duration_err1", "koi_duration_err2", "koi_depth_err1", "koi_depth_err2", "koi_prad_err1", "koi_prad_err2", "koi_teq_err1", "koi_teq_err2", "koi_insol_err1", "koi_insol_err2", "koi_tce_plnt_num", "koi_tce_delivname","koi_steff_err1", "koi_steff_err2", "koi_slogg_err1", "koi_slogg_err2", "koi_srad_err1", "koi_srad_err2", "koi_disposition_CANDIDATE", "koi_disposition_CONFIRMED", "koi_disposition_FALSE POSITIVE"], axis=1)
exoplanets_basic.dropna(axis=0)
#None found
exoplanets_basic
# Out:
#      kepoi_name  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0     K00752.01              0              0              0              0
# 1     K00752.02              0              0              0              0
# 2     K00753.01              0              1              0              0
# 3     K00754.01              0              1              0              0
# 4     K00755.01              0              0              0              0
# ...         ...            ...            ...            ...            ...
# 9559  K07984.01              0              0              0              1
# 9560  K07985.01              0              1              1              0
# 9561  K07986.01              0              0              0              0
# 9562  K07987.01              0              0              1              0
# 9563  K07989.01              0              0              1              1
#
#       koi_period  koi_time0bk  koi_impact  koi_duration  koi_depth  koi_prad  \
# 0       9.488036   170.538750       0.146       2.95750      615.8      2.26
# 1      54.418383   162.513840       0.586       4.50700      874.8      2.83
# 2      19.899140   175.850252       0.969       1.78220    10829.0     14.60
# 3       1.736952   170.307565       1.276       2.40641     8079.2     33.46
# 4       2.525592   171.595550       0.701       1.65450      603.3      2.75
# ...          ...          ...         ...           ...        ...       ...
# 9559    8.589871   132.016100       0.765       4.80600       87.7      1.11
# 9560    0.527699   131.705093       1.252       3.22210     1579.2     29.35
# 9561    1.739849   133.001270       0.043       3.11400       48.5      0.72
# 9562    0.681402   132.181750       0.147       0.86500      103.6      1.07
# 9563    4.856035   135.993300       0.134       3.07800       76.7      1.05
#
#       koi_teq  koi_insol  koi_model_snr  koi_steff  koi_slogg  koi_srad  \
# 0       793.0      93.59           35.8     5455.0      4.467     0.927
# 1       443.0       9.11           25.8     5455.0      4.467     0.927
# 2       638.0      39.30           76.3     5853.0      4.544     0.868
# 3      1395.0     891.96          505.6     5805.0      4.564     0.791
# 4      1406.0     926.16           40.9     6031.0      4.438     1.046
# ...       ...        ...            ...        ...        ...       ...
# 9559    929.0     176.40            8.4     5638.0      4.296     1.088
# 9560   2088.0    4500.53          453.3     5638.0      4.529     0.903
# 9561   1608.0    1585.81           10.6     6119.0      4.444     1.031
# 9562   2218.0    5713.41           12.3     6173.0      4.447     1.041
# 9563   1266.0     607.42            8.2     6469.0      4.385     1.193
#
#              ra        dec  koi_kepmag  koi_pdisposition_CANDIDATE
# 0     291.93423  48.141651      15.347                           1
# 1     291.93423  48.141651      15.347                           1
# 2     297.00482  48.134129      15.436                           0
# 3     285.53461  48.285210      15.597                           0
# 4     288.75488  48.226200      15.509                           1
# ...         ...        ...         ...                         ...
# 9559  298.74921  46.973351      14.478                           0
# 9560  297.18875  47.093819      14.082                           0
# 9561  286.50937  47.163219      14.757                           1
# 9562  294.16489  47.176281      15.385                           0
# 9563  297.00977  47.121021      14.826                           0
#
# [9564 rows x 21 columns]

# %%
#At least for Grid Search - need to change float64 to int64
exoplanets_basic.dtypes
# Out:
# kepoi_name                     object
# koi_fpflag_nt                   int64
# koi_fpflag_ss                   int64
# koi_fpflag_co                   int64
# koi_fpflag_ec                   int64
# koi_period                    float64
# koi_time0bk                   float64
# koi_impact                    float64
# koi_duration                  float64
# koi_depth                     float64
# koi_prad                      float64
# koi_teq                       float64
# koi_insol                     float64
# koi_model_snr                 float64
# koi_steff                     float64
# koi_slogg                     float64
# koi_srad                      float64
# ra                            float64
# dec                           float64
# koi_kepmag                    float64
# koi_pdisposition_CANDIDATE      uint8
# dtype: object

# %%
list(exoplanets_basic.columns)
# Out:
# ['kepoi_name',
#  'koi_fpflag_nt',
#  'koi_fpflag_ss',
#  'koi_fpflag_co',
#  'koi_fpflag_ec',
#  'koi_period',
#  'koi_time0bk',
#  'koi_impact',
#  'koi_duration',
#  'koi_depth',
#  'koi_prad',
#  'koi_teq',
#  'koi_insol',
#  'koi_model_snr',
#  'koi_steff',
#  'koi_slogg',
#  'koi_srad',
#  'ra',
#  'dec',
#  'koi_kepmag',
#  'koi_pdisposition_CANDIDATE']

# %%
#exoplanets_basic['koi_period','koi_time0bk','koi_impact','koi_duration','koi_depth','koi_prad','koi_teq','koi_insol','koi_model_snr','koi_steff',
#                 'koi_slogg','koi_srad','ra','dec','koi_kepmag'] = exoplanets_basic['koi_period','koi_time0bk','koi_impact','koi_duration','koi_depth','koi_prad','koi_teq','koi_insol','koi_model_snr','koi_steff','koi_slogg','koi_srad','ra','dec','koi_kepmag'].astype('int64')
#exoplanets_basic = exoplanets_basic.astype({'koi_period': 'int64','koi_time0bk': 'int64','koi_impact': 'int64','koi_duration': 'int64','koi_depth': 'int64','koi_prad': 'int64','koi_teq': 'int64','koi_insol': 'int64','koi_model_snr': 'int64','koi_steff': 'int64','koi_slogg': 'int64','koi_srad': 'int64','ra': 'int64','dec': 'int64','koi_kepmag': 'int64'})
#empDfObj = empDfObj.astype({'Age': 'float64', 'Marks': 'object'})
exoplanets_basic = exoplanets_basic.astype({'koi_period': 'int64'})
exoplanets_basic = exoplanets_basic.astype({'koi_time0bk': 'int64'})
#exoplanets_basic = exoplanets_basic.astype({'koi_impact': 'int64'})
exoplanets_basic = exoplanets_basic.astype({'koi_duration': 'int64'})
#exoplanets_basic = exoplanets_basic.astype({'koi_depth': 'int64'})
#exoplanets_basic = exoplanets_basic.astype({'koi_prad': 'int64'})
#exoplanets_basic = exoplanets_basic.astype({'koi_teq': 'int64'})
#exoplanets_basic = exoplanets_basic.astype({'koi_insol': 'int64'})
#exoplanets_basic = exoplanets_basic.astype({'koi_model_snr': 'int64'})
exoplanets_basic = exoplanets_basic.astype({'koi_steff': 'int64'})
exoplanets_basic = exoplanets_basic.astype({'koi_slogg': 'int64'})
exoplanets_basic = exoplanets_basic.astype({'koi_srad': 'int64'})
exoplanets_basic = exoplanets_basic.astype({'ra': 'int64'})
exoplanets_basic = exoplanets_basic.astype({'dec': 'int64'})
exoplanets_basic = exoplanets_basic.astype({'koi_kepmag': 'int64'})

exoplanets_basic.dtypes
# Out:
# kepoi_name                     object
# koi_fpflag_nt                   int64
# koi_fpflag_ss                   int64
# koi_fpflag_co                   int64
# koi_fpflag_ec                   int64
# koi_period                      int64
# koi_time0bk                     int64
# koi_impact                    float64
# koi_duration                    int64
# koi_depth                     float64
# koi_prad                      float64
# koi_teq                       float64
# koi_insol                     float64
# koi_model_snr                 float64
# koi_steff                     float64
# koi_slogg                     float64
# koi_srad                      float64
# ra                            float64
# dec                           float64
# koi_kepmag                    float64
# koi_pdisposition_CANDIDATE      uint8
# dtype: object

# %% [markdown]
# Grid Search

# %%
#This is included in Activity 10, not yet sure why
from sklearn.neighbors import KNeighborsClassifier

# %%
target = exoplanets_basic["koi_pdisposition_CANDIDATE"].values.reshape(-1,1)
target_names = ["False_positive", "Candidate"]

# %%
data = exoplanets_basic.drop(["koi_pdisposition_CANDIDATE", "kepoi_name"], axis=1)
feature_names = data.columns
data
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0                 0              0              0              0    9.488036
# 1                 0              0              0              0   54.418383
# 2                 0              1              0              0   19.899140
# 3                 0              1              0              0    1.736952
# 4                 0              0              0              0    2.525592
# ...             ...            ...            ...            ...         ...
# 9559              0              0              0              1    8.589871
# 9560              0              1              1              0    0.527699
# 9561              0              0              0              0    1.739849
# 9562              0              0              1              0    0.681402
# 9563              0              0              1              1    4.856035
#
#       koi_time0bk  koi_impact  koi_duration  koi_depth  koi_prad  koi_teq  \
# 0      170.538750       0.146       2.95750      615.8      2.26    793.0
# 1      162.513840       0.586       4.50700      874.8      2.83    443.0
# 2      175.850252       0.969       1.78220    10829.0     14.60    638.0
# 3      170.307565       1.276       2.40641     8079.2     33.46   1395.0
# 4      171.595550       0.701       1.65450      603.3      2.75   1406.0
# ...           ...         ...           ...        ...       ...      ...
# 9559   132.016100       0.765       4.80600       87.7      1.11    929.0
# 9560   131.705093       1.252       3.22210     1579.2     29.35   2088.0
# 9561   133.001270       0.043       3.11400       48.5      0.72   1608.0
# 9562   132.181750       0.147       0.86500      103.6      1.07   2218.0
# 9563   135.993300       0.134       3.07800       76.7      1.05   1266.0
#
#       koi_insol  koi_model_snr  koi_steff  koi_slogg  koi_srad         ra  \
# 0         93.59           35.8     5455.0      4.467     0.927  291.93423
# 1          9.11           25.8     5455.0      4.467     0.927  291.93423
# 2         39.30           76.3     5853.0      4.544     0.868  297.00482
# 3        891.96          505.6     5805.0      4.564     0.791  285.53461
# 4        926.16           40.9     6031.0      4.438     1.046  288.75488
# ...         ...            ...        ...        ...       ...        ...
# 9559     176.40            8.4     5638.0      4.296     1.088  298.74921
# 9560    4500.53          453.3     5638.0      4.529     0.903  297.18875
# 9561    1585.81           10.6     6119.0      4.444     1.031  286.50937
# 9562    5713.41           12.3     6173.0      4.447     1.041  294.16489
# 9563     607.42            8.2     6469.0      4.385     1.193  297.00977
#
#             dec  koi_kepmag
# 0     48.141651      15.347
# 1     48.141651      15.347
# 2     48.134129      15.436
# 3     48.285210      15.597
# 4     48.226200      15.509
# ...         ...         ...
# 9559  46.973351      14.478
# 9560  47.093819      14.082
# 9561  47.163219      14.757
# 9562  47.176281      15.385
# 9563  47.121021      14.826
#
# [9564 rows x 19 columns]

# %%
data.dtypes
# Out:
# koi_fpflag_nt      int64
# koi_fpflag_ss      int64
# koi_fpflag_co      int64
# koi_fpflag_ec      int64
# koi_period       float64
# koi_time0bk      float64
# koi_impact       float64
# koi_duration     float64
# koi_depth        float64
# koi_prad         float64
# koi_teq          float64
# koi_insol        float64
# koi_model_snr    float64
# koi_steff        float64
# koi_slogg        float64
# koi_srad         float64
# ra               float64
# dec              float64
# koi_kepmag       float64
# dtype: object

# %%
# Assign X (data) and y (target)

### BEGIN SOLUTION
#X = data[['Age', 'Height', 'Sex_Male', 'Smoker_Current']]
#y = data["FEV"].values.reshape(-1, 1)
#print(X.shape, y.shape)
### END SOLUTION

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=312)

# %%
#from sklearn.preprocessing import StandardScaler

# Create a StandardScater model and fit it to the training data


#X_scaler = StandardScaler().fit(X_train)
#y_scaler = StandardScaler().fit(y_train)

# %%
# Transform the training and testing data using the X_scaler and y_scaler models

### BEGIN SOLUTION
#X_train_scaled = X_scaler.transform(X_train)
#X_test_scaled = X_scaler.transform(X_test)
#y_train_scaled = y_scaler.transform(y_train)
#y_test_scaled = y_scaler.transform(y_test)
### END SOLUTION

# %%
# Support vector machine linear classifier
from sklearn.svm import SVC 
model = SVC(kernel='linear')

# %%
# Create the GridSearch estimator along with a parameter object containing the values to adjust
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [1, 5, 10],
              'gamma': [0.0001, 0.001, 0.01]}
grid = GridSearchCV(model, param_grid, verbose=3)

# %%
# Fit the model using the grid search estimator. 
# This will take the SVC model and try each combination of parameters
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ..................... C=1, gamma=0.0001, score=nan, total=   0.0s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ..................... C=1, gamma=0.0001, score=nan, total=   0.0s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ..................... C=1, gamma=0.0001, score=nan, total=   0.0s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ..................... C=1, gamma=0.0001, score=nan, total=   0.0s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ..................... C=1, gamma=0.0001, score=nan, total=   0.0s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ...................... C=1, gamma=0.001, score=nan, total=   0.0s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ...................... C=1, gamma=0.001, score=nan, total=   0.0s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ...................... C=1, gamma=0.001, score=nan, total=   0.0s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ...................... C=1, gamma=0.001, score=nan, total=   0.0s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ...................... C=1, gamma=0.001, score=nan, total=   0.0s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ....................... C=1, gamma=0.01, score=nan, total=   0.0s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ....................... C=1, gamma=0.01, score=nan, total=   0.0s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ....................... C=1, gamma=0.01, score=nan, total=   0.0s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ....................... C=1, gamma=0.01, score=nan, total=   0.0s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ....................... C=1, gamma=0.01, score=nan, total=   0.0s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ..................... C=5, gamma=0.0001, score=nan, total=   0.0s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ..................... C=5, gamma=0.0001, score=nan, total=   0.0s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ..................... C=5, gamma=0.0001, score=nan, total=   0.0s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ..................... C=5, gamma=0.0001, score=nan, total=   0.0s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ..................... C=5, gamma=0.0001, score=nan, total=   0.0s
# [CV] C=5, gamma=0.001 ................................................
# [CV] ...................... C=5, gamma=0.001, score=nan, total=   0.0s
# [CV] C=5, gamma=0.001 ................................................
# [CV] ...................... C=5, gamma=0.001, score=nan, total=   0.0s
# [CV] C=5, gamma=0.001 ................................................
# [CV] ...................... C=5, gamma=0.001, score=nan, total=   0.0s
# [CV] C=5, gamma=0.001 ................................................
# [CV] ...................... C=5, gamma=0.001, score=nan, total=   0.0s
# [CV] C=5, gamma=0.001 ................................................
# [CV] ...................... C=5, gamma=0.001, score=nan, total=   0.0s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ....................... C=5, gamma=0.01, score=nan, total=   0.0s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ....................... C=5, gamma=0.01, score=nan, total=   0.0s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ....................... C=5, gamma=0.01, score=nan, total=   0.0s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ....................... C=5, gamma=0.01, score=nan, total=   0.0s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ....................... C=5, gamma=0.01, score=nan, total=   0.0s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................... C=10, gamma=0.0001, score=nan, total=   0.0s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................... C=10, gamma=0.0001, score=nan, total=   0.0s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................... C=10, gamma=0.0001, score=nan, total=   0.0s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................... C=10, gamma=0.0001, score=nan, total=   0.0s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................... C=10, gamma=0.0001, score=nan, total=   0.0s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ..................... C=10, gamma=0.001, score=nan, total=   0.0s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ..................... C=10, gamma=0.001, score=nan, total=   0.0s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ..................... C=10, gamma=0.001, score=nan, total=   0.0s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ..................... C=10, gamma=0.001, score=nan, total=   0.0s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ..................... C=10, gamma=0.001, score=nan, total=   0.0s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ...................... C=10, gamma=0.01, score=nan, total=   0.0s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ...................... C=10, gamma=0.01, score=nan, total=   0.0s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ...................... C=10, gamma=0.01, score=nan, total=   0.0s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ...................... C=10, gamma=0.01, score=nan, total=   0.0s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ...................... C=10, gamma=0.01, score=nan, total=   0.0s
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/svm/_base.py", line 162, in fit
#     accept_large_sparse=False)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 645, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 99, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# /Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/svm/_base.py", line 162, in fit
#     accept_large_sparse=False)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 645, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 99, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# /Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/svm/_base.py", line 162, in fit
#     accept_large_sparse=False)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 645, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 99, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# /Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/svm/_base.py", line 162, in fit
#     accept_large_sparse=False)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 645, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 99, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# /Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/svm/_base.py", line 162, in fit
#     accept_large_sparse=False)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 645, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 99, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# /Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/svm/_base.py", line 162, in fit
#     accept_large_sparse=False)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 645, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 99, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# /Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/svm/_base.py", line 162, in fit
#     accept_large_sparse=False)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 645, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 99, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# /Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/svm/_base.py", line 162, in fit
#     accept_large_sparse=False)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 645, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 99, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# /Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/svm/_base.py", line 162, in fit
#     accept_large_sparse=False)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 645, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 99, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# /Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/svm/_base.py", line 162, in fit
#     accept_large_sparse=False)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 645, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 99, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# /Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/svm/_base.py", line 162, in fit
#     accept_large_sparse=False)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 645, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 99, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# /Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/svm/_base.py", line 162, in fit
#     accept_large_sparse=False)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 645, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 99, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# /Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/svm/_base.py", line 162, in fit
#     accept_large_sparse=False)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 645, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 99, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# /Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/svm/_base.py", line 162, in fit
#     accept_large_sparse=False)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 645, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 99, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# /Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/svm/_base.py", line 162, in fit
#     accept_large_sparse=False)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 645, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 99, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# /Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/svm/_base.py", line 162, in fit
#     accept_large_sparse=False)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 645, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 99, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# /Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/svm/_base.py", line 162, in fit
#     accept_large_sparse=False)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 645, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 99, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# /Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/svm/_base.py", line 162, in fit
#     accept_large_sparse=False)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 645, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 99, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# /Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/svm/_base.py", line 162, in fit
#     accept_large_sparse=False)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 645, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 99, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# /Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/svm/_base.py", line 162, in fit
#     accept_large_sparse=False)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 645, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 99, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# /Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/svm/_base.py", line 162, in fit
#     accept_large_sparse=False)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 645, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 99, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# /Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/svm/_base.py", line 162, in fit
#     accept_large_sparse=False)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 645, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 99, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# /Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/svm/_base.py", line 162, in fit
#     accept_large_sparse=False)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 645, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 99, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# /Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/svm/_base.py", line 162, in fit
#     accept_large_sparse=False)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
# ...
# Traceback (most recent call last):
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/svm/_base.py", line 162, in fit
#     accept_large_sparse=False)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 645, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 99, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# /Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/svm/_base.py", line 162, in fit
#     accept_large_sparse=False)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 645, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 99, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# /Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/svm/_base.py", line 162, in fit
#     accept_large_sparse=False)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 645, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 99, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# /Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/svm/_base.py", line 162, in fit
#     accept_large_sparse=False)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 645, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 99, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# /Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/svm/_base.py", line 162, in fit
#     accept_large_sparse=False)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 645, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 99, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# /Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/svm/_base.py", line 162, in fit
#     accept_large_sparse=False)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 645, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 99, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# /Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/svm/_base.py", line 162, in fit
#     accept_large_sparse=False)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 645, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/Users/bmacgreg/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py", line 99, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   FitFailedWarning)
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:    0.2s finished
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-40879d1d806d> in <module>
#       1 # Fit the model using the grid search estimator.
#       2 # This will take the SVC model and try each combination of parameters
# ----> 3 grid.fit(X_train_scaled, y_train_scaled)
#
# ~/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     763             refit_start_time = time.time()
#     764             if y is not None:
# --> 765                 self.best_estimator_.fit(X, y, **fit_params)
#     766             else:
#     767                 self.best_estimator_.fit(X, **fit_params)
#
# ~/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     160             X, y = self._validate_data(X, y, dtype=np.float64,
#     161                                        order='C', accept_sparse='csr',
# --> 162                                        accept_large_sparse=False)
#     163
#     164         y = self._validate_targets(y)
#
# ~/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ~/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     800                     ensure_min_samples=ensure_min_samples,
#     801                     ensure_min_features=ensure_min_features,
# --> 802                     estimator=estimator)
#     803     if multi_output:
#     804         y = check_array(y, accept_sparse='csr', force_all_finite=True,
#
# ~/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     643         if force_all_finite:
#     644             _assert_all_finite(array,
# --> 645                                allow_nan=force_all_finite == 'allow-nan')
#     646
#     647     if ensure_min_samples > 0:
#
# ~/opt/anaconda3/envs/PythonML/lib/python3.6/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      97                     msg_err.format
#      98                     (type_err,
# ---> 99                      msg_dtype if msg_dtype is not None else X.dtype)
#     100             )
#     101     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
