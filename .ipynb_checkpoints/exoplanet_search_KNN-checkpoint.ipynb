# %% [markdown]
# ## Import some dependencies

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Import and clean data

# %%
exoplanets = pd.read_csv(os.path.join('Resources', 'cumulative.csv'))
pd.set_option('display.max_columns', None)
exoplanets
# Out:
#       rowid     kepid kepoi_name   kepler_name koi_disposition  \
# 0         1  10797460  K00752.01  Kepler-227 b       CONFIRMED
# 1         2  10797460  K00752.02  Kepler-227 c       CONFIRMED
# 2         3  10811496  K00753.01           NaN  FALSE POSITIVE
# 3         4  10848459  K00754.01           NaN  FALSE POSITIVE
# 4         5  10854555  K00755.01  Kepler-664 b       CONFIRMED
# ...     ...       ...        ...           ...             ...
# 9559   9560  10031643  K07984.01           NaN  FALSE POSITIVE
# 9560   9561  10090151  K07985.01           NaN  FALSE POSITIVE
# 9561   9562  10128825  K07986.01           NaN       CANDIDATE
# 9562   9563  10147276  K07987.01           NaN  FALSE POSITIVE
# 9563   9564  10156110  K07989.01           NaN  FALSE POSITIVE
#
#      koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0           CANDIDATE      1.000              0              0              0
# 1           CANDIDATE      0.969              0              0              0
# 2      FALSE POSITIVE      0.000              0              1              0
# 3      FALSE POSITIVE      0.000              0              1              0
# 4           CANDIDATE      1.000              0              0              0
# ...               ...        ...            ...            ...            ...
# 9559   FALSE POSITIVE      0.000              0              0              0
# 9560   FALSE POSITIVE      0.000              0              1              1
# 9561        CANDIDATE      0.497              0              0              0
# 9562   FALSE POSITIVE      0.021              0              0              1
# 9563   FALSE POSITIVE      0.000              0              0              1
#
#       koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  \
# 0                 0    9.488036     2.775000e-05    -2.775000e-05
# 1                 0   54.418383     2.479000e-04    -2.479000e-04
# 2                 0   19.899140     1.494000e-05    -1.494000e-05
# 3                 0    1.736952     2.630000e-07    -2.630000e-07
# 4                 0    2.525592     3.761000e-06    -3.761000e-06
# ...             ...         ...              ...              ...
# 9559              1    8.589871     1.846000e-04    -1.846000e-04
# 9560              0    0.527699     1.160000e-07    -1.160000e-07
# 9561              0    1.739849     1.780000e-05    -1.780000e-05
# 9562              0    0.681402     2.434000e-06    -2.434000e-06
# 9563              1    4.856035     6.356000e-05    -6.356000e-05
#
#       koi_time0bk  koi_time0bk_err1  koi_time0bk_err2  koi_impact  \
# 0      170.538750          0.002160         -0.002160       0.146
# 1      162.513840          0.003520         -0.003520       0.586
# 2      175.850252          0.000581         -0.000581       0.969
# 3      170.307565          0.000115         -0.000115       1.276
# 4      171.595550          0.001130         -0.001130       0.701
# ...           ...               ...               ...         ...
# 9559   132.016100          0.015700         -0.015700       0.765
# 9560   131.705093          0.000170         -0.000170       1.252
# 9561   133.001270          0.007690         -0.007690       0.043
# 9562   132.181750          0.002850         -0.002850       0.147
# 9563   135.993300          0.010800         -0.010800       0.134
#
#       koi_impact_err1  koi_impact_err2  koi_duration  koi_duration_err1  \
# 0               0.318           -0.146       2.95750            0.08190
# 1               0.059           -0.443       4.50700            0.11600
# 2               5.126           -0.077       1.78220            0.03410
# 3               0.115           -0.092       2.40641            0.00537
# 4               0.235           -0.478       1.65450            0.04200
# ...               ...              ...           ...                ...
# 9559            0.023           -0.541       4.80600            0.63400
# 9560            0.051           -0.049       3.22210            0.01740
# 9561            0.423           -0.043       3.11400            0.22900
# 9562            0.309           -0.147       0.86500            0.16200
# 9563            0.323           -0.134       3.07800            0.28300
#
#       koi_duration_err2  koi_depth  koi_depth_err1  koi_depth_err2  koi_prad  \
# 0              -0.08190      615.8            19.5           -19.5      2.26
# 1              -0.11600      874.8            35.5           -35.5      2.83
# 2              -0.03410    10829.0           171.0          -171.0     14.60
# 3              -0.00537     8079.2            12.8           -12.8     33.46
# 4              -0.04200      603.3            16.9           -16.9      2.75
# ...                 ...        ...             ...             ...       ...
# 9559           -0.63400       87.7            13.0           -13.0      1.11
# 9560           -0.01740     1579.2             4.6            -4.6     29.35
# 9561           -0.22900       48.5             5.4            -5.4      0.72
# 9562           -0.16200      103.6            14.7           -14.7      1.07
# 9563           -0.28300       76.7            10.8           -10.8      1.05
#
#       koi_prad_err1  koi_prad_err2  koi_teq  koi_teq_err1  koi_teq_err2  \
# 0              0.26          -0.15    793.0           NaN           NaN
# 1              0.32          -0.19    443.0           NaN           NaN
# 2              3.92          -1.31    638.0           NaN           NaN
# 3              8.50          -2.83   1395.0           NaN           NaN
# 4              0.88          -0.35   1406.0           NaN           NaN
# ...             ...            ...      ...           ...           ...
# 9559           0.32          -0.23    929.0           NaN           NaN
# 9560           7.70          -2.57   2088.0           NaN           NaN
# 9561           0.24          -0.08   1608.0           NaN           NaN
# 9562           0.36          -0.11   2218.0           NaN           NaN
# 9563           0.36          -0.12   1266.0           NaN           NaN
#
#       koi_insol  koi_insol_err1  koi_insol_err2  koi_model_snr  \
# 0         93.59           29.45          -16.65           35.8
# 1          9.11            2.87           -1.62           25.8
# 2         39.30           31.04          -10.49           76.3
# 3        891.96          668.95         -230.35          505.6
# 4        926.16          874.33         -314.24           40.9
# ...         ...             ...             ...            ...
# 9559     176.40          152.77          -77.60            8.4
# 9560    4500.53         3406.38        -1175.26          453.3
# 9561    1585.81         1537.86         -502.22           10.6
# 9562    5713.41         5675.74        -1836.94           12.3
# 9563     607.42          600.39         -194.33            8.2
#
#       koi_tce_plnt_num koi_tce_delivname  koi_steff  koi_steff_err1  \
# 0                  1.0   q1_q17_dr25_tce     5455.0            81.0
# 1                  2.0   q1_q17_dr25_tce     5455.0            81.0
# 2                  1.0   q1_q17_dr25_tce     5853.0           158.0
# 3                  1.0   q1_q17_dr25_tce     5805.0           157.0
# 4                  1.0   q1_q17_dr25_tce     6031.0           169.0
# ...                ...               ...        ...             ...
# 9559               1.0   q1_q17_dr25_tce     5638.0           169.0
# 9560               1.0   q1_q17_dr25_tce     5638.0           139.0
# 9561               1.0   q1_q17_dr25_tce     6119.0           165.0
# 9562               1.0   q1_q17_dr25_tce     6173.0           193.0
# 9563               1.0   q1_q17_dr25_tce     6469.0           158.0
#
#       koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# 0              -81.0      4.467           0.064          -0.096     0.927
# 1              -81.0      4.467           0.064          -0.096     0.927
# 2             -176.0      4.544           0.044          -0.176     0.868
# 3             -174.0      4.564           0.053          -0.168     0.791
# 4             -211.0      4.438           0.070          -0.210     1.046
# ...              ...        ...             ...             ...       ...
# 9559          -152.0      4.296           0.231          -0.189     1.088
# 9560          -166.0      4.529           0.035          -0.196     0.903
# 9561          -220.0      4.444           0.056          -0.224     1.031
# 9562          -236.0      4.447           0.056          -0.224     1.041
# 9563          -225.0      4.385           0.054          -0.216     1.193
#
#       koi_srad_err1  koi_srad_err2         ra        dec  koi_kepmag
# 0             0.105         -0.061  291.93423  48.141651      15.347
# 1             0.105         -0.061  291.93423  48.141651      15.347
# 2             0.233         -0.078  297.00482  48.134129      15.436
# 3             0.201         -0.067  285.53461  48.285210      15.597
# 4             0.334         -0.133  288.75488  48.226200      15.509
# ...             ...            ...        ...        ...         ...
# 9559          0.313         -0.228  298.74921  46.973351      14.478
# 9560          0.237         -0.079  297.18875  47.093819      14.082
# 9561          0.341         -0.114  286.50937  47.163219      14.757
# 9562          0.341         -0.114  294.16489  47.176281      15.385
# 9563          0.410         -0.137  297.00977  47.121021      14.826
#
# [9564 rows x 50 columns]

# %%
#Remove rows (if any) where koi_pdisposition is not FALSE POSITIVE or CANDIDATE; koi_disposition has additional categories
exoplanets.koi_pdisposition.unique()
#None found in current file
# Out:
# array(['CANDIDATE', 'FALSE POSITIVE'], dtype=object)

# %%
#Make koi_pdisposition and koi_disposition numerical variables, see if they are the same (no, koi_disposition has more categories)
exoplanets_pdisp_cat = pd.get_dummies(exoplanets, prefix=['koi_pdisposition'], columns=['koi_pdisposition'])

# %%
exoplanets_disp_cat = pd.get_dummies(exoplanets_pdisp_cat, prefix=['koi_disposition'], columns=['koi_disposition'])
exoplanets_disp_cat.drop('koi_pdisposition_FALSE POSITIVE', axis=1, inplace=True)

# %%
exoplanets_basic = exoplanets_disp_cat.drop(["rowid", "kepoi_name", "kepler_name", "koi_score", "koi_period_err1", "koi_period_err2", "koi_time0bk_err1", "koi_time0bk_err2", "koi_impact_err1", "koi_impact_err2", "koi_duration_err1", "koi_duration_err2", "koi_depth_err1", "koi_depth_err2", "koi_prad_err1", "koi_prad_err2", "koi_teq_err1", "koi_teq_err2", "koi_insol_err1", "koi_insol_err2", "koi_tce_plnt_num", "koi_tce_delivname","koi_steff_err1", "koi_steff_err2", "koi_slogg_err1", "koi_slogg_err2", "koi_srad_err1", "koi_srad_err2", "koi_disposition_CANDIDATE", "koi_disposition_CONFIRMED", "koi_disposition_FALSE POSITIVE"], axis=1)
exoplanets_basic.rename(columns={'koi_fpflag_nt': 'flag_not_transit_like', 
                   'koi_fpflag_ss': 'flag_stellar_eclipse', 
                   'koi_fpflag_co': 'flag_centroid_offset',
                   'koi_fpflag_ec': 'flag_ephemeris match',                  
                   'koi_period': 'orbital_period',                  
                   'koi_time0bk': 'time_first_trans_detected',
                   'koi_impact': 'star_planet_dist_at_conj',                   
                   'koi_duration': 'trans_duration',                   
                   'koi_depth': 'stellar_flux_loss_at_trans_min',
                   'koi_prad': 'planet_radius',
                   'koi_teq': 'approx_planet_temp',
                   'koi_insol': 'insolation_flux',
                   'koi_model_snr': 'trans_sig_to_noise',
                   'koi_steff': 'stellar_eff_temp',
                   'koi_slogg': 'stellar_surf_gravity',
                   'koi_srad': 'stellar_photosph_rad',
                   'ra': 'sky_location_right_asc',
                   'dec': 'sky_location_declination',                   
                   'koi_kepmag': 'stellar_magnitude'}, inplace=True)
exoplanets_basic.dropna(axis=0)
#None found by this method
# Out:
#          kepid  flag_not_transit_like  flag_stellar_eclipse  \
# 0     10797460                      0                     0
# 1     10797460                      0                     0
# 2     10811496                      0                     1
# 3     10848459                      0                     1
# 4     10854555                      0                     0
# ...        ...                    ...                   ...
# 9559  10031643                      0                     0
# 9560  10090151                      0                     1
# 9561  10128825                      0                     0
# 9562  10147276                      0                     0
# 9563  10156110                      0                     0
#
#       flag_centroid_offset  flag_ephemeris match  orbital_period  \
# 0                        0                     0        9.488036
# 1                        0                     0       54.418383
# 2                        0                     0       19.899140
# 3                        0                     0        1.736952
# 4                        0                     0        2.525592
# ...                    ...                   ...             ...
# 9559                     0                     1        8.589871
# 9560                     1                     0        0.527699
# 9561                     0                     0        1.739849
# 9562                     1                     0        0.681402
# 9563                     1                     1        4.856035
#
#       time_first_trans_detected  star_planet_dist_at_conj  trans_duration  \
# 0                    170.538750                     0.146         2.95750
# 1                    162.513840                     0.586         4.50700
# 2                    175.850252                     0.969         1.78220
# 3                    170.307565                     1.276         2.40641
# 4                    171.595550                     0.701         1.65450
# ...                         ...                       ...             ...
# 9559                 132.016100                     0.765         4.80600
# 9560                 131.705093                     1.252         3.22210
# 9561                 133.001270                     0.043         3.11400
# 9562                 132.181750                     0.147         0.86500
# 9563                 135.993300                     0.134         3.07800
#
#       stellar_flux_loss_at_trans_min  planet_radius  approx_planet_temp  \
# 0                              615.8           2.26               793.0
# 1                              874.8           2.83               443.0
# 2                            10829.0          14.60               638.0
# 3                             8079.2          33.46              1395.0
# 4                              603.3           2.75              1406.0
# ...                              ...            ...                 ...
# 9559                            87.7           1.11               929.0
# 9560                          1579.2          29.35              2088.0
# 9561                            48.5           0.72              1608.0
# 9562                           103.6           1.07              2218.0
# 9563                            76.7           1.05              1266.0
#
#       insolation_flux  trans_sig_to_noise  stellar_eff_temp  \
# 0               93.59                35.8            5455.0
# 1                9.11                25.8            5455.0
# 2               39.30                76.3            5853.0
# 3              891.96               505.6            5805.0
# 4              926.16                40.9            6031.0
# ...               ...                 ...               ...
# 9559           176.40                 8.4            5638.0
# 9560          4500.53               453.3            5638.0
# 9561          1585.81                10.6            6119.0
# 9562          5713.41                12.3            6173.0
# 9563           607.42                 8.2            6469.0
#
#       stellar_surf_gravity  stellar_photosph_rad  sky_location_right_asc  \
# 0                    4.467                 0.927               291.93423
# 1                    4.467                 0.927               291.93423
# 2                    4.544                 0.868               297.00482
# 3                    4.564                 0.791               285.53461
# 4                    4.438                 1.046               288.75488
# ...                    ...                   ...                     ...
# 9559                 4.296                 1.088               298.74921
# 9560                 4.529                 0.903               297.18875
# 9561                 4.444                 1.031               286.50937
# 9562                 4.447                 1.041               294.16489
# 9563                 4.385                 1.193               297.00977
#
#       sky_location_declination  stellar_magnitude  koi_pdisposition_CANDIDATE
# 0                    48.141651             15.347                           1
# 1                    48.141651             15.347                           1
# 2                    48.134129             15.436                           0
# 3                    48.285210             15.597                           0
# 4                    48.226200             15.509                           1
# ...                        ...                ...                         ...
# 9559                 46.973351             14.478                           0
# 9560                 47.093819             14.082                           0
# 9561                 47.163219             14.757                           1
# 9562                 47.176281             15.385                           0
# 9563                 47.121021             14.826                           0
#
# [9200 rows x 21 columns]

# %%
np.any(np.isnan(exoplanets_basic))
# Out:
# True

# %%
np.all(np.isfinite(exoplanets_basic))
# Out:
# False

# %%
#https://stackoverflow.com/questions/31323499/sklearn-error-valueerror-input-contains-nan-infinity-or-a-value-too-large-for
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)
clean_dataset(exoplanets_basic)
exoplanets_basic
# Out:
#          kepid  flag_not_transit_like  flag_stellar_eclipse  \
# 0     10797460                      0                     0
# 1     10797460                      0                     0
# 2     10811496                      0                     1
# 3     10848459                      0                     1
# 4     10854555                      0                     0
# ...        ...                    ...                   ...
# 9559  10031643                      0                     0
# 9560  10090151                      0                     1
# 9561  10128825                      0                     0
# 9562  10147276                      0                     0
# 9563  10156110                      0                     0
#
#       flag_centroid_offset  flag_ephemeris match  orbital_period  \
# 0                        0                     0        9.488036
# 1                        0                     0       54.418383
# 2                        0                     0       19.899140
# 3                        0                     0        1.736952
# 4                        0                     0        2.525592
# ...                    ...                   ...             ...
# 9559                     0                     1        8.589871
# 9560                     1                     0        0.527699
# 9561                     0                     0        1.739849
# 9562                     1                     0        0.681402
# 9563                     1                     1        4.856035
#
#       time_first_trans_detected  star_planet_dist_at_conj  trans_duration  \
# 0                    170.538750                     0.146         2.95750
# 1                    162.513840                     0.586         4.50700
# 2                    175.850252                     0.969         1.78220
# 3                    170.307565                     1.276         2.40641
# 4                    171.595550                     0.701         1.65450
# ...                         ...                       ...             ...
# 9559                 132.016100                     0.765         4.80600
# 9560                 131.705093                     1.252         3.22210
# 9561                 133.001270                     0.043         3.11400
# 9562                 132.181750                     0.147         0.86500
# 9563                 135.993300                     0.134         3.07800
#
#       stellar_flux_loss_at_trans_min  planet_radius  approx_planet_temp  \
# 0                              615.8           2.26               793.0
# 1                              874.8           2.83               443.0
# 2                            10829.0          14.60               638.0
# 3                             8079.2          33.46              1395.0
# 4                              603.3           2.75              1406.0
# ...                              ...            ...                 ...
# 9559                            87.7           1.11               929.0
# 9560                          1579.2          29.35              2088.0
# 9561                            48.5           0.72              1608.0
# 9562                           103.6           1.07              2218.0
# 9563                            76.7           1.05              1266.0
#
#       insolation_flux  trans_sig_to_noise  stellar_eff_temp  \
# 0               93.59                35.8            5455.0
# 1                9.11                25.8            5455.0
# 2               39.30                76.3            5853.0
# 3              891.96               505.6            5805.0
# 4              926.16                40.9            6031.0
# ...               ...                 ...               ...
# 9559           176.40                 8.4            5638.0
# 9560          4500.53               453.3            5638.0
# 9561          1585.81                10.6            6119.0
# 9562          5713.41                12.3            6173.0
# 9563           607.42                 8.2            6469.0
#
#       stellar_surf_gravity  stellar_photosph_rad  sky_location_right_asc  \
# 0                    4.467                 0.927               291.93423
# 1                    4.467                 0.927               291.93423
# 2                    4.544                 0.868               297.00482
# 3                    4.564                 0.791               285.53461
# 4                    4.438                 1.046               288.75488
# ...                    ...                   ...                     ...
# 9559                 4.296                 1.088               298.74921
# 9560                 4.529                 0.903               297.18875
# 9561                 4.444                 1.031               286.50937
# 9562                 4.447                 1.041               294.16489
# 9563                 4.385                 1.193               297.00977
#
#       sky_location_declination  stellar_magnitude  koi_pdisposition_CANDIDATE
# 0                    48.141651             15.347                           1
# 1                    48.141651             15.347                           1
# 2                    48.134129             15.436                           0
# 3                    48.285210             15.597                           0
# 4                    48.226200             15.509                           1
# ...                        ...                ...                         ...
# 9559                 46.973351             14.478                           0
# 9560                 47.093819             14.082                           0
# 9561                 47.163219             14.757                           1
# 9562                 47.176281             15.385                           0
# 9563                 47.121021             14.826                           0
#
# [9200 rows x 21 columns]

# %%
np.any(np.isnan(exoplanets_basic))
# Out:
# False

# %%
np.all(np.isfinite(exoplanets_basic))
# Out:
# True

# %%
y = exoplanets_basic["koi_pdisposition_CANDIDATE"]
target_names = ["negative", "positive"]

# %%
X = exoplanets_basic.drop("koi_pdisposition_CANDIDATE", axis=1)

# %% [markdown]
# ## KNN, all columns

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=312)

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScater model and fit it to the training data

X_scaler = StandardScaler().fit(X_train)

# %%
# Transform the training and testing data using the X_scaler and y_scaler models

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
X_test_scaled
# Out:
# array([[ 1.56158032, -0.4569789 , -0.55726234, ...,  0.99976476,
#          1.73581323,  0.53558297],
#        [ 1.41838499,  2.18828485, -0.55726234, ..., -1.32581418,
#          1.55689431, -0.40914775],
#        [ 1.20472567, -0.4569789 , -0.55726234, ...,  1.23354013,
#          1.23693371, -0.68563651],
#        ...,
#        [-0.70098115, -0.4569789 , -0.55726234, ...,  1.58558183,
#         -0.76880135, -0.28002239],
#        [-1.13237947, -0.4569789 , -0.55726234, ...,  1.13735538,
#         -1.12463811, -0.45364858],
#        [ 0.5280948 , -0.4569789 ,  1.79448697, ..., -0.49658492,
#          0.46099305, -1.34512421]])

# %%
# Loop through different k values to see which has the highest accuracy
# Note: We only use odd numbers because we don't want any ties
train_scores = []
test_scores = []
for k in range(1, 40, 2):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_scaled, y_train)
    train_score = knn.score(X_train_scaled, y_train)
    test_score = knn.score(X_test_scaled, y_test)
    train_scores.append(train_score)
    test_scores.append(test_score)
    print(f"k: {k}, Train/Test Score: {train_score:.3f}/{test_score:.3f}")
    
    
plt.plot(range(1, 40, 2), train_scores, marker='o')
plt.plot(range(1, 40, 2), test_scores, marker="x")
plt.xlabel("k neighbors")
plt.ylabel("Testing accuracy Score")
plt.show()
# Out:
# k: 1, Train/Test Score: 1.000/0.979
# k: 3, Train/Test Score: 0.990/0.987
# k: 5, Train/Test Score: 0.989/0.986
# k: 7, Train/Test Score: 0.989/0.986
# k: 9, Train/Test Score: 0.988/0.986
# k: 11, Train/Test Score: 0.988/0.986
# k: 13, Train/Test Score: 0.988/0.986
# k: 15, Train/Test Score: 0.988/0.987
# k: 17, Train/Test Score: 0.987/0.986
# k: 19, Train/Test Score: 0.987/0.985
# k: 21, Train/Test Score: 0.987/0.984
# k: 23, Train/Test Score: 0.986/0.983
# k: 25, Train/Test Score: 0.986/0.983
# k: 27, Train/Test Score: 0.986/0.983
# k: 29, Train/Test Score: 0.985/0.983
# k: 31, Train/Test Score: 0.986/0.983
# k: 33, Train/Test Score: 0.985/0.983
# k: 35, Train/Test Score: 0.985/0.983
# k: 37, Train/Test Score: 0.985/0.983
# k: 39, Train/Test Score: 0.985/0.982

# %%
# Note that k: 15 seems to be the best choice for this dataset
knn = KNeighborsClassifier(n_neighbors=15)
knn.fit(X_train_scaled, y_train)
print('k=15 Test Acc: %.3f' % knn.score(X_test_scaled, y_test))
# Out:
# k=15 Test Acc: 0.987

# %% [markdown]
# ### Accuracy okay, not great

# %% [markdown]
# ## KNN, take out "flag" values

# %%
data_deflag = exoplanets_basic.drop(["koi_pdisposition_CANDIDATE", "kepid", 'flag_not_transit_like','flag_centroid_offset','flag_stellar_eclipse','flag_ephemeris match' ], axis=1)
feature_names = data_deflag.columns
target = exoplanets_basic["koi_pdisposition_CANDIDATE"]
target_names = ["False_positive", "Candidate"]
data_deflag
# Out:
#       orbital_period  time_first_trans_detected  star_planet_dist_at_conj  \
# 0           9.488036                 170.538750                     0.146
# 1          54.418383                 162.513840                     0.586
# 2          19.899140                 175.850252                     0.969
# 3           1.736952                 170.307565                     1.276
# 4           2.525592                 171.595550                     0.701
# ...              ...                        ...                       ...
# 9559        8.589871                 132.016100                     0.765
# 9560        0.527699                 131.705093                     1.252
# 9561        1.739849                 133.001270                     0.043
# 9562        0.681402                 132.181750                     0.147
# 9563        4.856035                 135.993300                     0.134
#
#       trans_duration  stellar_flux_loss_at_trans_min  planet_radius  \
# 0            2.95750                           615.8           2.26
# 1            4.50700                           874.8           2.83
# 2            1.78220                         10829.0          14.60
# 3            2.40641                          8079.2          33.46
# 4            1.65450                           603.3           2.75
# ...              ...                             ...            ...
# 9559         4.80600                            87.7           1.11
# 9560         3.22210                          1579.2          29.35
# 9561         3.11400                            48.5           0.72
# 9562         0.86500                           103.6           1.07
# 9563         3.07800                            76.7           1.05
#
#       approx_planet_temp  insolation_flux  trans_sig_to_noise  \
# 0                  793.0            93.59                35.8
# 1                  443.0             9.11                25.8
# 2                  638.0            39.30                76.3
# 3                 1395.0           891.96               505.6
# 4                 1406.0           926.16                40.9
# ...                  ...              ...                 ...
# 9559               929.0           176.40                 8.4
# 9560              2088.0          4500.53               453.3
# 9561              1608.0          1585.81                10.6
# 9562              2218.0          5713.41                12.3
# 9563              1266.0           607.42                 8.2
#
#       stellar_eff_temp  stellar_surf_gravity  stellar_photosph_rad  \
# 0               5455.0                 4.467                 0.927
# 1               5455.0                 4.467                 0.927
# 2               5853.0                 4.544                 0.868
# 3               5805.0                 4.564                 0.791
# 4               6031.0                 4.438                 1.046
# ...                ...                   ...                   ...
# 9559            5638.0                 4.296                 1.088
# 9560            5638.0                 4.529                 0.903
# 9561            6119.0                 4.444                 1.031
# 9562            6173.0                 4.447                 1.041
# 9563            6469.0                 4.385                 1.193
#
#       sky_location_right_asc  sky_location_declination  stellar_magnitude
# 0                  291.93423                 48.141651             15.347
# 1                  291.93423                 48.141651             15.347
# 2                  297.00482                 48.134129             15.436
# 3                  285.53461                 48.285210             15.597
# 4                  288.75488                 48.226200             15.509
# ...                      ...                       ...                ...
# 9559               298.74921                 46.973351             14.478
# 9560               297.18875                 47.093819             14.082
# 9561               286.50937                 47.163219             14.757
# 9562               294.16489                 47.176281             15.385
# 9563               297.00977                 47.121021             14.826
#
# [9200 rows x 15 columns]

# %%
y = exoplanets_basic["koi_pdisposition_CANDIDATE"]
target_names = ["negative", "positive"]

# %%
X = data_deflag

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=312)

# %%
X_scaler = StandardScaler().fit(X_train)

# %%
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
X_test_scaled
# Out:
# array([[-4.18670155e-02, -3.85249694e-01, -1.98149916e-01, ...,
#          9.99764761e-01,  1.73581323e+00,  5.35582968e-01],
#        [-1.44438456e-03,  6.09062823e-01, -7.94895317e-03, ...,
#         -1.32581418e+00,  1.55689431e+00, -4.09147749e-01],
#        [-4.71185436e-02,  1.90263036e-01, -1.69294815e-01, ...,
#          1.23354013e+00,  1.23693371e+00, -6.85636508e-01],
#        ...,
#        [-4.85810685e-02, -4.87097840e-01, -5.49531045e-02, ...,
#          1.58558183e+00, -7.68801347e-01, -2.80022393e-01],
#        [-4.76609881e-02, -4.86608177e-01, -2.47496337e-02, ...,
#          1.13735538e+00, -1.12463811e+00, -4.53648578e-01],
#        [-4.95279407e-02, -5.12101915e-01, -2.87947414e-02, ...,
#         -4.96584919e-01,  4.60993054e-01, -1.34512421e+00]])

# %%
# Loop through different k values to see which has the highest accuracy
# Note: We only use odd numbers because we don't want any ties
train_scores = []
test_scores = []
for k in range(1, 50, 2):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_scaled, y_train)
    train_score = knn.score(X_train_scaled, y_train)
    test_score = knn.score(X_test_scaled, y_test)
    train_scores.append(train_score)
    test_scores.append(test_score)
    print(f"k: {k}, Train/Test Score: {train_score:.3f}/{test_score:.3f}")
    
    
plt.plot(range(1, 50, 2), train_scores, marker='o')
plt.plot(range(1, 50, 2), test_scores, marker="x")
plt.xlabel("k neighbors")
plt.ylabel("Testing accuracy Score")
plt.show()
# Out:
# k: 1, Train/Test Score: 1.000/0.723
# k: 3, Train/Test Score: 0.860/0.734
# k: 5, Train/Test Score: 0.824/0.752
# k: 7, Train/Test Score: 0.813/0.751
# k: 9, Train/Test Score: 0.803/0.757
# k: 11, Train/Test Score: 0.796/0.757
# k: 13, Train/Test Score: 0.788/0.762
# k: 15, Train/Test Score: 0.784/0.751
# k: 17, Train/Test Score: 0.777/0.761
# k: 19, Train/Test Score: 0.775/0.761
# k: 21, Train/Test Score: 0.773/0.753
# k: 23, Train/Test Score: 0.772/0.760
# k: 25, Train/Test Score: 0.769/0.758
# k: 27, Train/Test Score: 0.767/0.755
# k: 29, Train/Test Score: 0.764/0.753
# k: 31, Train/Test Score: 0.762/0.751
# k: 33, Train/Test Score: 0.762/0.755
# k: 35, Train/Test Score: 0.756/0.753
# k: 37, Train/Test Score: 0.755/0.750
# k: 39, Train/Test Score: 0.754/0.748
# k: 41, Train/Test Score: 0.753/0.749
# k: 43, Train/Test Score: 0.752/0.750
# k: 45, Train/Test Score: 0.751/0.749
# k: 47, Train/Test Score: 0.750/0.746
# k: 49, Train/Test Score: 0.751/0.746

# %%
# Note that k: 17 might be the best choice for this dataset
knn = KNeighborsClassifier(n_neighbors=17)
knn.fit(X_train_scaled, y_train)
print('k=17 Test Acc: %.3f' % knn.score(X_test_scaled, y_test))
# Out:
# k=17 Test Acc: 0.761

# %% [markdown]
# ### Accuracy comparable when "flag" columns removed
